# %%
import os
import gym
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
import random
import numpy as np


from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # types of spaces
# - there are 4 key spaces: discrete, box, multi-binary, miulti-discrete
# - 2 wrapper spaces: tuple(not supported by stable-baselines), dict

# %%
Discrete(3).sample()
# Out:
# 0

# %%
Box(0, 1, shape=(3,3)).sample()
# Out:
# array([[0.15012637, 0.86877924, 0.18370081],
#        [0.4061565 , 0.62263924, 0.9744529 ],
#        [0.89537174, 0.72817314, 0.8255071 ]], dtype=float32)

# %%
Tuple((Discrete(3), Box(0, 1, shape=(3,)))).sample()
# Out:
# (1, array([0.84669524, 0.3917245 , 0.8238068 ], dtype=float32))

# %%
Dict({'height': Discrete(3), 'speed': Box(0, 1, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 1), ('speed', array([0.88877785], dtype=float32))])

# %%
MultiBinary(4).sample()
# Out:
# array([1, 0, 1, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2,5]).sample()
# Out:
# array([2, 1, 0, 3], dtype=int64)

# %% [markdown]
# # building an env
# - build agent to give best shower
# - temp bw 37 and 39 degree

# %%
class ShowerEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)          #here 3 is passed to denote 3 conditions: turn tap on, off, unchanged
        self.observation_space = Box(low= 0, high= 0, shape=(1,))
        self.state = 38 + random.randint(-3,3)    # temp can start from 38 +/- 3
        self.shower_length = 60                   #time is passed as 60 seconds
        
        
    def step(self, action):
        self.state += action-1
        self.shower_length -= 1
        
        #calculate reward
        if self.state >=37 and self.state<=39:
            reward = 1
        else:
            reward = -1
            
            
        if self.shower_length <= 0:
            done = True
        else:
            done = False
            
        
        info={}
        return self.state, reward, done, info
    
    
    def render(self):
        #implement viz
        pass
    
    
    def reset(self):
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        self.shower_length = 60
        return self.state

# %%
env = ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([0.], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.reset()
# Out:
# array([37.])

# %%
# explanaiton of self.state += action-1

# action space is Discrete(3)
# which gives either 0,1,2
# therfore, action-1 gives -1,0,1
# -1 reduces shower temp
# 0 keeps it same
# 1 increases temp

# %% [markdown]
# # test environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    done = False
    score = 0
    state = env.reset()

    while not done:
        env.render()
        action = env.action_space.sample()
        #next_state, reward, terminated, truncated , info = env.step(action)
        n_state, reward, done, info = env.step(action)
        score += reward
        print('Episode: {} Score: {}'.format(episode, score))
env.close()
# Out:
# Episode: 1 Score: 1
# Episode: 1 Score: 2
# Episode: 1 Score: 1
# Episode: 1 Score: 0
# Episode: 1 Score: -1
# Episode: 1 Score: -2
# Episode: 1 Score: -3
# Episode: 1 Score: -4
# Episode: 1 Score: -5
# Episode: 1 Score: -6
# Episode: 1 Score: -7
# Episode: 1 Score: -8
# Episode: 1 Score: -9
# Episode: 1 Score: -10
# Episode: 1 Score: -11
# Episode: 1 Score: -12
# Episode: 1 Score: -13
|
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.363        |
# |    explained_variance   | 0.0452        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 49            |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 2.51e-05      |
# |    value_loss           | 108           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -2.52         |
# | time/                   |               |
# |    fps                  | 777           |
# |    iterations           | 8             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00086760335 |
# |    clip_fraction        | 0.0126        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.344        |
# |    explained_variance   | 0.1           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 50.8          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000913     |
# |    value_loss           | 103           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.66        |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 9            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0006100406 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | 0.0502       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00016     |
# |    value_loss           | 116          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.84        |
# | time/                   |              |
# |    fps                  | 769          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0022586095 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.325       |
# |    explained_variance   | 0.088        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.9         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -3.92        |
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 11           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0012039059 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.288       |
# |    explained_variance   | -0.00646     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.4         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000112     |
# |    value_loss           | 122          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -5.96         |
# | time/                   |               |
# |    fps                  | 743           |
# |    iterations           | 12            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00051883096 |
# |    clip_fraction        | 0.0107        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.279        |
# |    explained_variance   | 0.0588        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 69.6          |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 0.00027       |
# |    value_loss           | 132           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -4.5         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 13           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0007753848 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | 0.0311       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.7         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000402    |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.88        |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 14           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0056478293 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.0559       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56           |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00286      |
# |    value_loss           | 132          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -12.2        |
# | time/                   |              |
# |    fps                  | 751          |
# |    iterations           | 15           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009630142 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -0.132       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00115      |
# |    value_loss           | 108          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -10.6         |
# | time/                   |               |
# |    fps                  | 754           |
# |    iterations           | 16            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00031700952 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.226        |
# |    explained_variance   | 0.0173        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 55.3          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | 6.71e-05      |
# |    value_loss           | 123           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.1         |
# | time/                   |               |
# |    fps                  | 760           |
# |    iterations           | 17            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00018421351 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.249        |
# |    explained_variance   | 0.0501        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 69.6          |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -5.87e-06     |
# |    value_loss           | 138           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -9.28        |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 18           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0013991588 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | 0.0575       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.7         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 115          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -4.38         |
# | time/                   |               |
# |    fps                  | 769           |
# |    iterations           | 19            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00030489263 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.23         |
# |    explained_variance   | 0.0731        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 68.3          |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -5.69e-05     |
# |    value_loss           | 139           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -0.68         |
# | time/                   |               |
# |    fps                  | 773           |
# |    iterations           | 20            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00040709163 |
# |    clip_fraction        | 0.00459       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.226        |
# |    explained_variance   | 0.0948        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 67.7          |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000221     |
# |    value_loss           | 125           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -0.74         |
# | time/                   |               |
# |    fps                  | 777           |
# |    iterations           | 21            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00024644413 |
# |    clip_fraction        | 0.0022        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.223        |
# |    explained_variance   | 0.145         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.9          |
# |    n_updates            | 580           |
# |    policy_gradient_loss | 3.81e-05      |
# |    value_loss           | 128           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -13.4        |
# | time/                   |              |
# |    fps                  | 782          |
# |    iterations           | 22           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 8.003251e-05 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.1         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -9.95e-05    |
# |    value_loss           | 124          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.8        |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 23           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0002655743 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.9         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.000264     |
# |    value_loss           | 85           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -21.7        |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 24           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0005505305 |
# |    clip_fraction        | 0.00459      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.097        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.6         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000573    |
# |    value_loss           | 125          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -17.4         |
# | time/                   |               |
# |    fps                  | 793           |
# |    iterations           | 25            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00073840935 |
# |    clip_fraction        | 0.016         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.177        |
# |    explained_variance   | 0.115         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 68            |
# |    n_updates            | 620           |
# |    policy_gradient_loss | -0.00141      |
# |    value_loss           | 132           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -13.8        |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 26           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0005614712 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.174       |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.8         |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 124          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.5        |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 27           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0005884926 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.148       |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.7         |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.000291    |
# |    value_loss           | 128          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.4         |
# | time/                   |               |
# |    fps                  | 798           |
# |    iterations           | 28            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00062715914 |
# |    clip_fraction        | 0.0061        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.148        |
# |    explained_variance   | 0.231         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 63.5          |
# |    n_updates            | 650           |
# |    policy_gradient_loss | -0.000978     |
# |    value_loss           | 135           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -5.4          |
# | time/                   |               |
# |    fps                  | 799           |
# |    iterations           | 29            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00018223497 |
# |    clip_fraction        | 0.00649       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.147        |
# |    explained_variance   | 0.29          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 61.5          |
# |    n_updates            | 660           |
# |    policy_gradient_loss | 7.34e-05      |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -6.5          |
# | time/                   |               |
# |    fps                  | 799           |
# |    iterations           | 30            |
# |    time_elapsed         | 76            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00053660595 |
# |    clip_fraction        | 0.00757       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.13         |
# |    explained_variance   | 0.268         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 59            |
# |    n_updates            | 670           |
# |    policy_gradient_loss | -0.000294     |
# |    value_loss           | 130           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -3           |
# | time/                   |              |
# |    fps                  | 801          |
# |    iterations           | 31           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0005655456 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.7         |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.000303    |
# |    value_loss           | 128          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -8.38         |
# | time/                   |               |
# |    fps                  | 801           |
# |    iterations           | 32            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00040562922 |
# |    clip_fraction        | 0.00142       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | 0.425         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 56.6          |
# |    n_updates            | 690           |
# |    policy_gradient_loss | -0.000207     |
# |    value_loss           | 131           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -8.92         |
# | time/                   |               |
# |    fps                  | 801           |
# |    iterations           | 33            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00022700094 |
# |    clip_fraction        | 0.00264       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.107        |
# |    explained_variance   | 0.37          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 71.6          |
# |    n_updates            | 700           |
# |    policy_gradient_loss | -0.000275     |
# |    value_loss           | 127           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -7.52         |
# | time/                   |               |
# |    fps                  | 802           |
# |    iterations           | 34            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00048925565 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0952       |
# |    explained_variance   | 0.457         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.00021      |
# |    value_loss           | 127           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.3         |
# | time/                   |               |
# |    fps                  | 801           |
# |    iterations           | 35            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00032391516 |
# |    clip_fraction        | 0.00444       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0913       |
# |    explained_variance   | 0.4           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 52            |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.000419     |
# |    value_loss           | 121           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -12          |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 36           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0002204373 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0817      |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.6         |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.000201    |
# |    value_loss           | 111          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -18.3        |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 37           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0005159024 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0897      |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.1         |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00067     |
# |    value_loss           | 123          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -12.7         |
# | time/                   |               |
# |    fps                  | 804           |
# |    iterations           | 38            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 1.5987665e-05 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0996       |
# |    explained_variance   | 0.536         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 49.5          |
# |    n_updates            | 750           |
# |    policy_gradient_loss | -1.6e-05      |
# |    value_loss           | 118           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.6        |
# | time/                   |              |
# |    fps                  | 803          |
# |    iterations           | 39           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0030382928 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.11        |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.8         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 114          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -6.56         |
# | time/                   |               |
# |    fps                  | 803           |
# |    iterations           | 40            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00032964154 |
# |    clip_fraction        | 0.00415       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.114        |
# |    explained_variance   | 0.569         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 59.8          |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -0.000107     |
# |    value_loss           | 129           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -0.92         |
# | time/                   |               |
# |    fps                  | 805           |
# |    iterations           | 41            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00070015306 |
# |    clip_fraction        | 0.0122        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.115        |
# |    explained_variance   | 0.618         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 61.5          |
# |    n_updates            | 780           |
# |    policy_gradient_loss | 0.000275      |
# |    value_loss           | 108           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.66         |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 42           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0011627006 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0991      |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56           |
# |    n_updates            | 790          |
# |    policy_gradient_loss | 4.78e-05     |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 3.26         |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 43           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0005638461 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.5         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000503    |
# |    value_loss           | 110          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -2.24         |
# | time/                   |               |
# |    fps                  | 808           |
# |    iterations           | 44            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00024646588 |
# |    clip_fraction        | 0.00532       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.118        |
# |    explained_variance   | 0.576         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 50.3          |
# |    n_updates            | 810           |
# |    policy_gradient_loss | 0.000112      |
# |    value_loss           | 118           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 45           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018642915 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.138       |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.9         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 112          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -14.3         |
# | time/                   |               |
# |    fps                  | 807           |
# |    iterations           | 46            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00013566142 |
# |    clip_fraction        | 0.00864       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.119        |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 61.1          |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000425     |
# |    value_loss           | 112           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11           |
# | time/                   |               |
# |    fps                  | 806           |
# |    iterations           | 47            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00012377143 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.127        |
# |    explained_variance   | 0.629         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 45.1          |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 110           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -13          |
# | time/                   |              |
# |    fps                  | 806          |
# |    iterations           | 48           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0009506765 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.5         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.3        |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 49           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 9.114854e-06 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0981      |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.5         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.000166    |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.2        |
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 50           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0005121934 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0967      |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.7         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000638    |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -4.64        |
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 51           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0022092601 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0781      |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.5         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 109          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -2.26         |
# | time/                   |               |
# |    fps                  | 777           |
# |    iterations           | 52            |
# |    time_elapsed         | 136           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00022643106 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0705       |
# |    explained_variance   | 0.712         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 43.9          |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -0.000424     |
# |    value_loss           | 93.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -4.38         |
# | time/                   |               |
# |    fps                  | 763           |
# |    iterations           | 53            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00024546852 |
# |    clip_fraction        | 0.00596       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0729       |
# |    explained_variance   | 0.765         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 59.4          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -0.000774     |
# |    value_loss           | 102           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# ...
# |    clip_fraction        | 0.00962      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0942      |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.7         |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -18.4       |
# | time/                   |             |
# |    fps                  | 654         |
# |    iterations           | 68          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.005906781 |
# |    clip_fraction        | 0.00884     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.2        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | 0.000903    |
# |    value_loss           | 111         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -16.3         |
# | time/                   |               |
# |    fps                  | 650           |
# |    iterations           | 69            |
# |    time_elapsed         | 217           |
# |    total_timesteps      | 141312        |
# | train/                  |               |
# |    approx_kl            | 0.00042140414 |
# |    clip_fraction        | 0.00493       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0854       |
# |    explained_variance   | 0.747         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 101           |
# |    n_updates            | 1060          |
# |    policy_gradient_loss | 0.000354      |
# |    value_loss           | 136           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.3         |
# | time/                   |               |
# |    fps                  | 645           |
# |    iterations           | 70            |
# |    time_elapsed         | 221           |
# |    total_timesteps      | 143360        |
# | train/                  |               |
# |    approx_kl            | 0.00042949372 |
# |    clip_fraction        | 0.00264       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0829       |
# |    explained_variance   | 0.783         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 48            |
# |    n_updates            | 1070          |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 98.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.9         |
# | time/                   |               |
# |    fps                  | 641           |
# |    iterations           | 71            |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 145408        |
# | train/                  |               |
# |    approx_kl            | 0.00040046542 |
# |    clip_fraction        | 0.0043        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0824       |
# |    explained_variance   | 0.798         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 46.3          |
# |    n_updates            | 1080          |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 117           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -5.26        |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 72           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0002625258 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0937      |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.5         |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | 0.000292     |
# |    value_loss           | 121          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -8.6          |
# | time/                   |               |
# |    fps                  | 632           |
# |    iterations           | 73            |
# |    time_elapsed         | 236           |
# |    total_timesteps      | 149504        |
# | train/                  |               |
# |    approx_kl            | 0.00039738676 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0807       |
# |    explained_variance   | 0.82          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 79.4          |
# |    n_updates            | 1100          |
# |    policy_gradient_loss | -0.000399     |
# |    value_loss           | 114           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -13.2         |
# | time/                   |               |
# |    fps                  | 628           |
# |    iterations           | 74            |
# |    time_elapsed         | 241           |
# |    total_timesteps      | 151552        |
# | train/                  |               |
# |    approx_kl            | 0.00020469734 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0736       |
# |    explained_variance   | 0.81          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 61.4          |
# |    n_updates            | 1110          |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 121           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -15.4         |
# | time/                   |               |
# |    fps                  | 625           |
# |    iterations           | 75            |
# |    time_elapsed         | 245           |
# |    total_timesteps      | 153600        |
# | train/                  |               |
# |    approx_kl            | 0.00029985933 |
# |    clip_fraction        | 0.00381       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0782       |
# |    explained_variance   | 0.811         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 48.8          |
# |    n_updates            | 1120          |
# |    policy_gradient_loss | -0.000867     |
# |    value_loss           | 103           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -18.4         |
# | time/                   |               |
# |    fps                  | 621           |
# |    iterations           | 76            |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 0.00022193429 |
# |    clip_fraction        | 0.00283       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0687       |
# |    explained_variance   | 0.822         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 55.3          |
# |    n_updates            | 1130          |
# |    policy_gradient_loss | -0.000229     |
# |    value_loss           | 117           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -11.3         |
# | time/                   |               |
# |    fps                  | 618           |
# |    iterations           | 77            |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 157696        |
# | train/                  |               |
# |    approx_kl            | 4.3875654e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.066        |
# |    explained_variance   | 0.805         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 42.6          |
# |    n_updates            | 1140          |
# |    policy_gradient_loss | -6.65e-05     |
# |    value_loss           | 115           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -4.16         |
# | time/                   |               |
# |    fps                  | 617           |
# |    iterations           | 78            |
# |    time_elapsed         | 258           |
# |    total_timesteps      | 159744        |
# | train/                  |               |
# |    approx_kl            | 0.00012883666 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0594       |
# |    explained_variance   | 0.83          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 41.3          |
# |    n_updates            | 1150          |
# |    policy_gradient_loss | -0.00054      |
# |    value_loss           | 115           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -6.94         |
# | time/                   |               |
# |    fps                  | 613           |
# |    iterations           | 79            |
# |    time_elapsed         | 263           |
# |    total_timesteps      | 161792        |
# | train/                  |               |
# |    approx_kl            | 0.00015161658 |
# |    clip_fraction        | 0.00415       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0522       |
# |    explained_variance   | 0.811         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 73            |
# |    n_updates            | 1160          |
# |    policy_gradient_loss | -0.000322     |
# |    value_loss           | 124           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 80          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.002312121 |
# |    clip_fraction        | 0.00527     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0587     |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.5        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 122         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -8.56         |
# | time/                   |               |
# |    fps                  | 603           |
# |    iterations           | 81            |
# |    time_elapsed         | 274           |
# |    total_timesteps      | 165888        |
# | train/                  |               |
# |    approx_kl            | 4.0731044e-05 |
# |    clip_fraction        | 0.00205       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0685       |
# |    explained_variance   | 0.844         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 53.8          |
# |    n_updates            | 1180          |
# |    policy_gradient_loss | 9.34e-05      |
# |    value_loss           | 124           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -4.44       |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 82          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.000129689 |
# |    clip_fraction        | 0.00229     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0711     |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.8        |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.000343   |
# |    value_loss           | 117         |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 model.learn(total_timesteps = 200000)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:281, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     278         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     279         self.logger.dump(step=self.num_timesteps)
# --> 281     self.train()
#     283 callback.on_training_end()
#     285 return self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:261, in PPO.train(self)
#     259 with th.no_grad():
#     260     log_ratio = log_prob - rollout_data.old_log_prob
# --> 261     approx_kl_div = th.mean((th.exp(log_ratio) - 1) - log_ratio).cpu().numpy()
#     262     approx_kl_divs.append(approx_kl_div)
#     264 if self.target_kl is not None and approx_kl_div > 1.5 * self.target_kl:
#
# KeyboardInterrupt:

# %%
shower_path = os.path.join('Training', 'Saved Models', 'Shower_model_ppo')

# %%
model.save(shower_path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# [0] indicates reward
# [1] indicates variance
# Out:
# (12.0, 58.787753826796276)
